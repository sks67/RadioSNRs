# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
nsnrs = np.loadtxt('paramtst_nsnrs.txt')
time = np.logspace(3.0,7.0,500)
plt.plot(time,nsnrs)
plt.xscale('log')
plt.ylabel('N',fontsize=15)
plt.xlabel('t [years]',fontsize=15)
plt.yscale('log')
#plt.ylim(1,200)
#plt.xlim(1.0e3,1.0e7)
plt.show()

# %%
array = 10**(np.random.normal(loc=51.0,scale=0.28,size=1000000)-51.0)
bns = np.logspace(np.log10(array.min()),np.log10(array.max()),100)
plt.hist(array,bins=bns,histtype='step',color='k')
plt.xlabel(r'$E_{51}$',fontsize=15)
#plt.xlim(8,10.0)
#lt.ylim(0,100)
plt.xscale('log')
plt.show()

# %%
e51 = 2.0
n0 = 100.0
vrad = 188*((e51/(n0**2))**0.07)
print vrad
# Out:
# 103.569039582
