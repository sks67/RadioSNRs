# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
diam = 2.0*np.loadtxt('paramtst_diamhist.txt')
print diam.shape
print diam
# Out:
# (30, 6000)
# [[  829.70835449   827.7850111    590.4513115  ...,     0.             0.
#       0.        ]
#  [ 1207.34676816  1040.72293921   569.03960529 ...,     0.             0.
#       0.        ]
#  [ 1017.98610983   582.21635252   447.81441636 ...,     0.             0.
#       0.        ]
#  ...,
#  [  994.9461581    633.7851521    503.12449409 ...,     0.             0.
#       0.        ]
#  [  930.62709775   720.56626055   591.96775359 ...,     0.             0.
#       0.        ]
#  [ 1386.98604059  1071.26755217   697.89809846 ...,     0.             0.
#       0.        ]]

# %% [markdown]
# ## Cumulative Histogram

# %%
import os
path = '../Inputs/lmc_angdiams.txt'
dist = 0.05 #Mpc
lmcdiams_ang = np.loadtxt(path)
lmcdiams_temp = ((lmcdiams_ang*np.pi)/(180.0*3600.0))*dist*(1.0e6)
n1, bin1, patches1 = plt.hist(lmcdiams_temp,bins=10000,color='g',lw=3.0,histtype='step',cumulative=1)
#plt.axvline(2.0e23,linestyle='--',lw=1.5,color='k')
for ind,diams in enumerate(diam):
    diams = diams[np.nonzero(diams)]
    n2, bins2, patches2 = plt.hist(diams,bins=10000,histtype='step',color='purple',cumulative=1,alpha=0.16)

#patches2[0].set_xy(patches2[0].get_xy()[1:])
#patches1[0].set_xy(patches1[0].get_xy()[1:])
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Diameter[pc]',fontsize=15)
plt.ylabel('N',fontsize=15)
plt.title(r'$f=0.22,\ d=60pc,\ R=2.0\times10^{-3}$',fontsize=15)
ax = plt.gca()
ax.tick_params(labelsize=15)
plt.ylim(0,500)
#userdoc = os.path.join(os.getcwd(),'Plots')
plt.xlim(0,2.0e2)
plt.tight_layout()
fig = plt.gcf()
#fig.set_size_inches((8,6))
#plt.savefig(os.path.join(userdoc,'DiamHist_f05d20.png'))
plt.show()
print bin1
# Out:
# [  0.00000000e+00   1.61685363e-02   3.23370725e-02 ...,   1.61653026e+02
#    1.61669194e+02   1.61685363e+02]

# %% [markdown]
# ## Differential Histogram

# %%
diam_cutoff = lmcdiams.max() #pc      
lmcdiams=lmcdiams_temp
diam_mean = np.mean(diams,axis=0)
diam_err = np.mean(diams,axis=0)
obs_bins = np.linspace(0,diam_cutoff,6)
plt.hist(lmcdiams,bins=obs_bins,histtype='step',lw=3.0)
n2 = np.zeros((diam_array.shape[0],obs_bins.size-1))
for ind,diams in enumerate(diam):
    diams = diams[np.nonzero(diams)]
    n2[ind],bins=np.histogram(diams,bins=obs_bins)

diam_mean = np.mean(n2,axis=0)
diam_err = np.std(n2,ddof=1,axis=0)
plt.errorbar(obs_bins[:-1]+15.0,diam_mean,yerr=diam_err,fmt='o',ecolor='r')
plt.xlabel('Diameter [pc]',fontsize=15)
plt.legend()
plt.show()

# %% [markdown]
# ## Cubic Density Histogram

# %%
dens = np.loadtxt('paramtst_denshist.txt')
array = dens[49][np.nonzero(dens[49])]
dens_bins = np.logspace(np.log10(array.min()),np.log10(array.max()),6)
plt.hist(array,bins=dens_bins,lw=2,color='r',alpha=0.5)
plt.xscale('log')
plt.xlabel(r'$n_i\ [cm^{-3}]$',fontsize=25)
plt.ylabel(r'$N$',fontsize=25)
plt.show()

# %%
from scipy.interpolate import interp2d

thick = np.loadtxt('checksnaps_easier_thickness.txt')
frac = np.loadtxt('checksnaps_easier_fraction.txt')
likelihood = np.loadtxt('checksnaps_easier_likelihood.txt').reshape(thick.size,frac.size)

F,T = np.meshgrid(frac,thick)
np.set_printoptions(precision=4)
#print T,'\n',F,'\n'
thicknew = np.linspace(thick.min(),thick.max(),500)
fracnew = np.linspace(frac.min(),frac.max(),500)
f = interp2d(frac,thick,likelihood,kind='linear')
likhood_new = f(fracnew,thicknew)
print T[0:3]
print F[0:3]
print likelihood[0:3]
# Out:
# [[ 10.  10.  10.  10.  10.  10.  10.  10.  10.  10.]
#  [ 20.  20.  20.  20.  20.  20.  20.  20.  20.  20.]
#  [ 30.  30.  30.  30.  30.  30.  30.  30.  30.  30.]]
# [[ 0.2     0.2889  0.3778  0.4667  0.5556  0.6444  0.7333  0.8222  0.9111
#    1.    ]
#  [ 0.2     0.2889  0.3778  0.4667  0.5556  0.6444  0.7333  0.8222  0.9111
#    1.    ]
#  [ 0.2     0.2889  0.3778  0.4667  0.5556  0.6444  0.7333  0.8222  0.9111
#    1.    ]]
# [[  2.6135e-18   2.3840e-14   6.0516e-14   5.7293e-13   4.8021e-13
#     6.2396e-12   6.9279e-12   1.0074e-11   3.6400e-11   2.5659e-10]
#  [  7.6146e-13   4.1653e-11   1.8366e-09   1.1277e-08   7.0480e-09
#     2.8405e-08   8.3283e-08   1.9821e-07   3.8434e-07   3.5036e-07]
#  [  3.5080e-11   4.0018e-09   1.0147e-07   2.7520e-07   6.4894e-07
#     4.3695e-07   2.6603e-06   2.2264e-06   5.3635e-06   2.8561e-06]]

# %%
import os
plt.figure(figsize=(7,6))
plt.contourf(fracnew,thicknew,likhood_new,cmap='autumn_r')
#plt.title('5x5 (f,d), ks-test,cutoff=2.0e23',fontsize=18)
plt.xlabel('Fraction (Ia/CC)',fontsize=20)
plt.ylabel('Scale Height[pc]',fontsize=20)
ax = plt.gca()
ax.tick_params(labelsize=15)
plt.colorbar(format='%.1e')
#userdoc = os.path.join(os.getcwd(),'Plots')
#plt.savefig(os.path.join(userdoc,'7'))
#plt.ylim(1,30)
plt.show()
print likelihood
# Out:
# [[  2.6135e-18   2.3840e-14   6.0516e-14   5.7293e-13   4.8021e-13
#     6.2396e-12   6.9279e-12   1.0074e-11   3.6400e-11   2.5659e-10]
#  [  7.6146e-13   4.1653e-11   1.8366e-09   1.1277e-08   7.0480e-09
#     2.8405e-08   8.3283e-08   1.9821e-07   3.8434e-07   3.5036e-07]
#  [  3.5080e-11   4.0018e-09   1.0147e-07   2.7520e-07   6.4894e-07
#     4.3695e-07   2.6603e-06   2.2264e-06   5.3635e-06   2.8561e-06]
#  [  1.4350e-09   5.6663e-08   5.2434e-07   9.8185e-07   1.4398e-06
#     2.5107e-06   2.6854e-06   2.6052e-06   6.1678e-06   8.1820e-06]
#  [  5.1272e-09   2.5353e-07   1.6859e-06   9.2776e-07   2.9952e-06
#     3.4775e-06   7.2383e-06   2.1405e-06   1.3992e-06   1.0482e-06]
#  [  1.7895e-08   3.5634e-07   1.2954e-06   2.1473e-06   2.2488e-06
#     1.5612e-06   1.8114e-06   3.1950e-06   1.0341e-06   3.7146e-06]
#  [  3.3043e-08   5.6074e-07   1.5514e-06   1.1478e-06   4.2877e-06
#     3.9680e-06   6.8589e-07   6.1024e-07   1.1607e-06   5.5581e-07]
#  [  1.8814e-07   3.4925e-07   1.3588e-06   9.5529e-07   1.4730e-06
#     1.8449e-06   2.3996e-07   2.2246e-07   1.1852e-07   8.5339e-08]
#  [  1.6596e-07   3.1924e-07   5.0630e-07   1.4480e-07   1.2469e-06
#     5.4768e-07   2.4644e-07   7.2193e-08   1.2345e-07   1.5691e-07]
#  [  3.2094e-07   5.6786e-07   1.7502e-07   2.6138e-07   3.1271e-07
#     3.3289e-07   1.2722e-07   4.7992e-08   1.2008e-08   1.5268e-08]]
