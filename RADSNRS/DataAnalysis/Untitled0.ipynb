# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = np.linspace(0,4,500)+0.001
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)
y4 = np.log(x)
y5 = x**2
y6 = 1.0/x
plt.figure(1,figsize=(10,9))
plt.subplot(331)
plt.plot(x,y1,'r-')
ax = plt.gca()
ax.get_xaxis().set_visible(False)
plt.subplot(334)
plt.plot(x,y2,'r-')
ax = plt.gca()
ax.get_xaxis().set_visible(False)
plt.subplot(335)
plt.plot(x,y3,'r-')
ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.subplot(337)
plt.plot(x,y4,'r-')
plt.subplot(338)
plt.plot(x,y5,'r-')
plt.subplot(339)
plt.plot(x,y6,'r-')
plt.show()
